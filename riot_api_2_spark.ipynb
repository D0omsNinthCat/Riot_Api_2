# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, round

#load from postgres
#master = "local[*] creates as many worker threads as logical cores on your machine"
spark = SparkSession.builder.appName("Riot_Api2").config("spark.jars", "postgresql-42.2.25.jre7.jar").master(master = "local[*]").getOrCreate()

# %% [markdown]
# # Load from JSON

# %%
import pyspark.sql.functions as F
#read Matchdata from JSON source
matches_from_json = spark.read.format("json").option("inferSchema", "true").option("multiLine", "true").load("matchlist.json")

# %%
#alot of useless/heavily nested information
matches_from_json.printSchema()
# Out:
# root
#  |-- info: struct (nullable = true)
#  |    |-- gameCreation: long (nullable = true)
#  |    |-- gameDuration: long (nullable = true)
#  |    |-- gameEndTimestamp: long (nullable = true)
#  |    |-- gameId: long (nullable = true)
#  |    |-- gameMode: string (nullable = true)
#  |    |-- gameName: string (nullable = true)
#  |    |-- gameStartTimestamp: long (nullable = true)
#  |    |-- gameType: string (nullable = true)
#  |    |-- gameVersion: string (nullable = true)
#  |    |-- mapId: long (nullable = true)
#  |    |-- participants: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- assists: long (nullable = true)
#  |    |    |    |-- baronKills: long (nullable = true)
#  |    |    |    |-- bountyLevel: long (nullable = true)
#  |    |    |    |-- challenges: struct (nullable = true)
#  |    |    |    |    |-- 12AssistStreakCount: long (nullable = true)
#  |    |    |    |    |-- abilityUses: long (nullable = true)
#  |    |    |    |    |-- acesBefore15Minutes: long (nullable = true)
#  |    |    |    |    |-- alliedJungleMonsterKills: double (nullable = true)
#  |    |    |    |    |-- baronBuffGoldAdvantageOverThreshold: long (nullable = true)
#  |    |    |    |    |-- baronTakedowns: long (nullable = true)
#  |    |    |    |    |-- blastConeOppositeOpponentCount: long (nullable = true)
#  |    |    |    |    |-- bountyGold: long (nullable = true)
#  |    |    |    |    |-- buffsStolen: long (nullable = true)
#  |    |    |    |    |-- completeSupportQuestInTime: long (nullable = true)
#  |    |    |    |    |-- controlWardTimeCoverageInRiverOrEnemyHalf: double (nullable = true)
#  |    |    |    |    |-- controlWardsPlaced: long (nullable = true)
#  |    |    |    |    |-- damagePerMinute: double (nullable = true)
#  |    |    |    |    |-- damageTakenOnTeamPercentage: double (nullable = true)
#  |    |    |    |    |-- dancedWithRiftHerald: long (nullable = true)
#  |    |    |    |    |-- deathsByEnemyChamps: long (nullable = true)
#  |    |    |    |    |-- dodgeSkillShotsSmallWindow: long (nullable = true)
#  |    |    |    |    |-- doubleAces: long (nullable = true)
#  |    |    |    |    |-- dragonTakedowns: long (nullable = true)
#  |    |    |    |    |-- earliestBaron: double (nullable = true)
#  |    |    |    |    |-- earliestDragonTakedown: double (nullable = true)
#  |    |    |    |    |-- earliestElderDragon: double (nullable = true)
#  |    |    |    |    |-- earlyLaningPhaseGoldExpAdvantage: double (nullable = true)
#  |    |    |    |    |-- effectiveHealAndShielding: double (nullable = true)
#  |    |    |    |    |-- elderDragonKillsWithOpposingSoul: long (nullable = true)
#  |    |    |    |    |-- elderDragonMultikills: long (nullable = true)
#  |    |    |    |    |-- enemyChampionImmobilizations: long (nullable = true)
#  |    |    |    |    |-- enemyJungleMonsterKills: double (nullable = true)
#  |    |    |    |    |-- epicMonsterKillsNearEnemyJungler: long (nullable = true)
#  |    |    |    |    |-- epicMonsterKillsWithin30SecondsOfSpawn: long (nullable = true)
#  |    |    |    |    |-- epicMonsterSteals: long (nullable = true)
#  |    |    |    |    |-- epicMonsterStolenWithoutSmite: long (nullable = true)
#  |    |    |    |    |-- fasterSupportQuestCompletion: long (nullable = true)
#  |    |    |    |    |-- fastestLegendary: double (nullable = true)
#  |    |    |    |    |-- firstTurretKilledTime: double (nullable = true)
#  |    |    |    |    |-- flawlessAces: long (nullable = true)
#  |    |    |    |    |-- fullTeamTakedown: long (nullable = true)
#  |    |    |    |    |-- gameLength: double (nullable = true)
#  |    |    |    |    |-- getTakedownsInAllLanesEarlyJungleAsLaner: long (nullable = true)
#  |    |    |    |    |-- goldPerMinute: double (nullable = true)
#  |    |    |    |    |-- hadAfkTeammate: long (nullable = true)
#  |    |    |    |    |-- hadOpenNexus: long (nullable = true)
#  |    |    |    |    |-- highestChampionDamage: long (nullable = true)
#  |    |    |    |    |-- highestCrowdControlScore: long (nullable = true)
#  |    |    |    |    |-- highestWardKills: long (nullable = true)
#  |    |    |    |    |-- immobilizeAndKillWithAlly: long (nullable = true)
#  |    |    |    |    |-- initialBuffCount: long (nullable = true)
#  |    |    |    |    |-- initialCrabCount: long (nullable = true)
#  |    |    |    |    |-- jungleCsBefore10Minutes: double (nullable = true)
#  |    |    |    |    |-- junglerKillsEarlyJungle: long (nullable = true)
#  |    |    |    |    |-- junglerTakedownsNearDamagedEpicMonster: long (nullable = true)
#  |    |    |    |    |-- kTurretsDestroyedBeforePlatesFall: long (nullable = true)
#  |    |    |    |    |-- kda: double (nullable = true)
#  |    |    |    |    |-- killAfterHiddenWithAlly: long (nullable = true)
#  |    |    |    |    |-- killParticipation: double (nullable = true)
#  |    |    |    |    |-- killedChampTookFullTeamDamageSurvived: long (nullable = true)
#  |    |    |    |    |-- killsNearEnemyTurret: long (nullable = true)
#  |    |    |    |    |-- killsOnLanersEarlyJungleAsJungler: long (nullable = true)
#  |    |    |    |    |-- killsOnOtherLanesEarlyJungleAsLaner: long (nullable = true)
#  |    |    |    |    |-- killsOnRecentlyHealedByAramPack: long (nullable = true)
#  |    |    |    |    |-- killsUnderOwnTurret: long (nullable = true)
#  |    |    |    |    |-- killsWithHelpFromEpicMonster: long (nullable = true)
#  |    |    |    |    |-- knockEnemyIntoTeamAndKill: long (nullable = true)
#  |    |    |    |    |-- landSkillShotsEarlyGame: long (nullable = true)
#  |    |    |    |    |-- laneMinionsFirst10Minutes: long (nullable = true)
#  |    |    |    |    |-- laningPhaseGoldExpAdvantage: double (nullable = true)
#  |    |    |    |    |-- legendaryCount: long (nullable = true)
#  |    |    |    |    |-- lostAnInhibitor: long (nullable = true)
#  |    |    |    |    |-- maxCsAdvantageOnLaneOpponent: double (nullable = true)
#  |    |    |    |    |-- maxKillDeficit: long (nullable = true)
#  |    |    |    |    |-- maxLevelLeadLaneOpponent: long (nullable = true)
#  |    |    |    |    |-- mejaisFullStackInTime: double (nullable = true)
#  |    |    |    |    |-- moreEnemyJungleThanOpponent: double (nullable = true)
#  |    |    |    |    |-- multiKillOneSpell: long (nullable = true)
#  |    |    |    |    |-- multiTurretRiftHeraldCount: long (nullable = true)
#  |    |    |    |    |-- multikills: long (nullable = true)
#  |    |    |    |    |-- multikillsAfterAggressiveFlash: long (nullable = true)
#  |    |    |    |    |-- mythicItemUsed: long (nullable = true)
#  |    |    |    |    |-- outerTurretExecutesBefore10Minutes: long (nullable = true)
#  |    |    |    |    |-- outnumberedKills: long (nullable = true)
#  |    |    |    |    |-- outnumberedNexusKill: long (nullable = true)
#  |    |    |    |    |-- perfectDragonSoulsTaken: long (nullable = true)
#  |    |    |    |    |-- perfectGame: long (nullable = true)
#  |    |    |    |    |-- pickKillWithAlly: long (nullable = true)
#  |    |    |    |    |-- poroExplosions: long (nullable = true)
#  |    |    |    |    |-- quickCleanse: long (nullable = true)
#  |    |    |    |    |-- quickFirstTurret: long (nullable = true)
#  |    |    |    |    |-- quickSoloKills: long (nullable = true)
#  |    |    |    |    |-- riftHeraldTakedowns: long (nullable = true)
#  |    |    |    |    |-- saveAllyFromDeath: long (nullable = true)
#  |    |    |    |    |-- scuttleCrabKills: long (nullable = true)
#  |    |    |    |    |-- shortestTimeToAceFromFirstTakedown: double (nullable = true)
#  |    |    |    |    |-- skillshotsDodged: long (nullable = true)
#  |    |    |    |    |-- skillshotsHit: long (nullable = true)
#  |    |    |    |    |-- snowballsHit: long (nullable = true)
#  |    |    |    |    |-- soloBaronKills: long (nullable = true)
#  |    |    |    |    |-- soloKills: long (nullable = true)
#  |    |    |    |    |-- soloTurretsLategame: long (nullable = true)
#  |    |    |    |    |-- stealthWardsPlaced: long (nullable = true)
#  |    |    |    |    |-- survivedSingleDigitHpCount: long (nullable = true)
#  |    |    |    |    |-- survivedThreeImmobilizesInFight: long (nullable = true)
#  |    |    |    |    |-- takedownOnFirstTurret: long (nullable = true)
#  |    |    |    |    |-- takedowns: long (nullable = true)
#  |    |    |    |    |-- takedownsAfterGainingLevelAdvantage: long (nullable = true)
#  |    |    |    |    |-- takedownsBeforeJungleMinionSpawn: long (nullable = true)
#  |    |    |    |    |-- takedownsFirst25Minutes: long (nullable = true)
#  |    |    |    |    |-- takedownsInAlcove: long (nullable = true)
#  |    |    |    |    |-- takedownsInEnemyFountain: long (nullable = true)
#  |    |    |    |    |-- teamBaronKills: long (nullable = true)
#  |    |    |    |    |-- teamDamagePercentage: double (nullable = true)
#  |    |    |    |    |-- teamElderDragonKills: long (nullable = true)
#  |    |    |    |    |-- teamRiftHeraldKills: long (nullable = true)
#  |    |    |    |    |-- teleportTakedowns: long (nullable = true)
#  |    |    |    |    |-- thirdInhibitorDestroyedTime: double (nullable = true)
#  |    |    |    |    |-- threeWardsOneSweeperCount: long (nullable = true)
#  |    |    |    |    |-- tookLargeDamageSurvived: long (nullable = true)
#  |    |    |    |    |-- turretPlatesTaken: long (nullable = true)
#  |    |    |    |    |-- turretTakedowns: long (nullable = true)
#  |    |    |    |    |-- turretsTakenWithRiftHerald: long (nullable = true)
#  |    |    |    |    |-- twentyMinionsIn3SecondsCount: long (nullable = true)
#  |    |    |    |    |-- unseenRecalls: long (nullable = true)
#  |    |    |    |    |-- visionScoreAdvantageLaneOpponent: double (nullable = true)
#  |    |    |    |    |-- visionScorePerMinute: double (nullable = true)
#  |    |    |    |    |-- wardTakedowns: long (nullable = true)
#  |    |    |    |    |-- wardTakedownsBefore20M: long (nullable = true)
#  |    |    |    |    |-- wardsGuarded: long (nullable = true)
#  |    |    |    |-- champExperience: long (nullable = true)
#  |    |    |    |-- champLevel: long (nullable = true)
#  |    |    |    |-- championId: long (nullable = true)
#  |    |    |    |-- championName: string (nullable = true)
#  |    |    |    |-- championTransform: long (nullable = true)
#  |    |    |    |-- consumablesPurchased: long (nullable = true)
#  |    |    |    |-- damageDealtToBuildings: long (nullable = true)
#  |    |    |    |-- damageDealtToObjectives: long (nullable = true)
#  |    |    |    |-- damageDealtToTurrets: long (nullable = true)
#  |    |    |    |-- damageSelfMitigated: long (nullable = true)
#  |    |    |    |-- deaths: long (nullable = true)
#  |    |    |    |-- detectorWardsPlaced: long (nullable = true)
#  |    |    |    |-- doubleKills: long (nullable = true)
#  |    |    |    |-- dragonKills: long (nullable = true)
#  |    |    |    |-- firstBloodAssist: boolean (nullable = true)
#  |    |    |    |-- firstBloodKill: boolean (nullable = true)
#  |    |    |    |-- firstTowerAssist: boolean (nullable = true)
#  |    |    |    |-- firstTowerKill: boolean (nullable = true)
#  |    |    |    |-- gameEndedInEarlySurrender: boolean (nullable = true)
#  |    |    |    |-- gameEndedInSurrender: boolean (nullable = true)
#  |    |    |    |-- goldEarned: long (nullable = true)
#  |    |    |    |-- goldSpent: long (nullable = true)
#  |    |    |    |-- individualPosition: string (nullable = true)
#  |    |    |    |-- inhibitorKills: long (nullable = true)
#  |    |    |    |-- inhibitorTakedowns: long (nullable = true)
#  |    |    |    |-- inhibitorsLost: long (nullable = true)
#  |    |    |    |-- item0: long (nullable = true)
#  |    |    |    |-- item1: long (nullable = true)
#  |    |    |    |-- item2: long (nullable = true)
#  |    |    |    |-- item3: long (nullable = true)
#  |    |    |    |-- item4: long (nullable = true)
#  |    |    |    |-- item5: long (nullable = true)
#  |    |    |    |-- item6: long (nullable = true)
#  |    |    |    |-- itemsPurchased: long (nullable = true)
#  |    |    |    |-- killingSprees: long (nullable = true)
#  |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |-- lane: string (nullable = true)
#  |    |    |    |-- largestCriticalStrike: long (nullable = true)
#  |    |    |    |-- largestKillingSpree: long (nullable = true)
#  |    |    |    |-- largestMultiKill: long (nullable = true)
#  |    |    |    |-- longestTimeSpentLiving: long (nullable = true)
#  |    |    |    |-- magicDamageDealt: long (nullable = true)
#  |    |    |    |-- magicDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- magicDamageTaken: long (nullable = true)
#  |    |    |    |-- neutralMinionsKilled: long (nullable = true)
#  |    |    |    |-- nexusKills: long (nullable = true)
#  |    |    |    |-- nexusLost: long (nullable = true)
#  |    |    |    |-- nexusTakedowns: long (nullable = true)
#  |    |    |    |-- objectivesStolen: long (nullable = true)
#  |    |    |    |-- objectivesStolenAssists: long (nullable = true)
#  |    |    |    |-- participantId: long (nullable = true)
#  |    |    |    |-- pentaKills: long (nullable = true)
#  |    |    |    |-- perks: struct (nullable = true)
#  |    |    |    |    |-- statPerks: struct (nullable = true)
#  |    |    |    |    |    |-- defense: long (nullable = true)
#  |    |    |    |    |    |-- flex: long (nullable = true)
#  |    |    |    |    |    |-- offense: long (nullable = true)
#  |    |    |    |    |-- styles: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- selections: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- perk: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- var1: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- var2: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- var3: long (nullable = true)
#  |    |    |    |    |    |    |-- style: long (nullable = true)
#  |    |    |    |-- physicalDamageDealt: long (nullable = true)
#  |    |    |    |-- physicalDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- physicalDamageTaken: long (nullable = true)
#  |    |    |    |-- profileIcon: long (nullable = true)
#  |    |    |    |-- puuid: string (nullable = true)
#  |    |    |    |-- quadraKills: long (nullable = true)
#  |    |    |    |-- riotIdName: string (nullable = true)
#  |    |    |    |-- riotIdTagline: string (nullable = true)
#  |    |    |    |-- role: string (nullable = true)
#  |    |    |    |-- sightWardsBoughtInGame: long (nullable = true)
#  |    |    |    |-- spell1Casts: long (nullable = true)
#  |    |    |    |-- spell2Casts: long (nullable = true)
#  |    |    |    |-- spell3Casts: long (nullable = true)
#  |    |    |    |-- spell4Casts: long (nullable = true)
#  |    |    |    |-- summoner1Casts: long (nullable = true)
#  |    |    |    |-- summoner1Id: long (nullable = true)
#  |    |    |    |-- summoner2Casts: long (nullable = true)
#  |    |    |    |-- summoner2Id: long (nullable = true)
#  |    |    |    |-- summonerId: string (nullable = true)
#  |    |    |    |-- summonerLevel: long (nullable = true)
#  |    |    |    |-- summonerName: string (nullable = true)
#  |    |    |    |-- teamEarlySurrendered: boolean (nullable = true)
#  |    |    |    |-- teamId: long (nullable = true)
#  |    |    |    |-- teamPosition: string (nullable = true)
#  |    |    |    |-- timeCCingOthers: long (nullable = true)
#  |    |    |    |-- timePlayed: long (nullable = true)
#  |    |    |    |-- totalDamageDealt: long (nullable = true)
#  |    |    |    |-- totalDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- totalDamageShieldedOnTeammates: long (nullable = true)
#  |    |    |    |-- totalDamageTaken: long (nullable = true)
#  |    |    |    |-- totalHeal: long (nullable = true)
#  |    |    |    |-- totalHealsOnTeammates: long (nullable = true)
#  |    |    |    |-- totalMinionsKilled: long (nullable = true)
#  |    |    |    |-- totalTimeCCDealt: long (nullable = true)
#  |    |    |    |-- totalTimeSpentDead: long (nullable = true)
#  |    |    |    |-- totalUnitsHealed: long (nullable = true)
#  |    |    |    |-- tripleKills: long (nullable = true)
#  |    |    |    |-- trueDamageDealt: long (nullable = true)
#  |    |    |    |-- trueDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- trueDamageTaken: long (nullable = true)
#  |    |    |    |-- turretKills: long (nullable = true)
#  |    |    |    |-- turretTakedowns: long (nullable = true)
#  |    |    |    |-- turretsLost: long (nullable = true)
#  |    |    |    |-- unrealKills: long (nullable = true)
#  |    |    |    |-- visionScore: long (nullable = true)
#  |    |    |    |-- visionWardsBoughtInGame: long (nullable = true)
#  |    |    |    |-- wardsKilled: long (nullable = true)
#  |    |    |    |-- wardsPlaced: long (nullable = true)
#  |    |    |    |-- win: boolean (nullable = true)
#  |    |-- platformId: string (nullable = true)
#  |    |-- queueId: long (nullable = true)
#  |    |-- teams: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- bans: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- championId: long (nullable = true)
#  |    |    |    |    |    |-- pickTurn: long (nullable = true)
#  |    |    |    |-- objectives: struct (nullable = true)
#  |    |    |    |    |-- baron: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- champion: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- dragon: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- inhibitor: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- riftHerald: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |    |-- tower: struct (nullable = true)
#  |    |    |    |    |    |-- first: boolean (nullable = true)
#  |    |    |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |-- teamId: long (nullable = true)
#  |    |    |    |-- win: boolean (nullable = true)
#  |    |-- tournamentCode: string (nullable = true)
#  |-- metadata: struct (nullable = true)
#  |    |-- dataVersion: string (nullable = true)
#  |    |-- matchId: string (nullable = true)
#  |    |-- participants: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)

# %%
#extract the wanted columns, still nested
participants_nested = matches_from_json.select(col("metadata.participants"), col("metadata.matchId"))
participants_nested.printSchema()
# Out:
# root
#  |-- participants: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- matchId: string (nullable = true)

# %%
#explode participants. to have a unique matchId for further DB storage, we need to explode differently
participants_not_unique = participants_nested.select(participants_nested.matchId,F.explode(participants_nested.participants))
participants_not_unique.show()

# %%
participants_unique = participants_nested.select("matchId", participants_nested.participants[0], participants_nested.participants[1], participants_nested.participants[2], participants_nested.participants[3], participants_nested.participants[4], participants_nested.participants[5], participants_nested.participants[6], participants_nested.participants[7], participants_nested.participants[8], participants_nested.participants[9])
participants_unique.printSchema()
# Out:
# root
#  |-- matchId: string (nullable = true)
#  |-- participants[0]: string (nullable = true)
#  |-- participants[1]: string (nullable = true)
#  |-- participants[2]: string (nullable = true)
#  |-- participants[3]: string (nullable = true)
#  |-- participants[4]: string (nullable = true)
#  |-- participants[5]: string (nullable = true)
#  |-- participants[6]: string (nullable = true)
#  |-- participants[7]: string (nullable = true)
#  |-- participants[8]: string (nullable = true)
#  |-- participants[9]: string (nullable = true)

# %%
#extract the player Details plus the matchId
player_details = matches_from_json.select(col("info.participants"), col("metadata.matchId"))
#the details are in a struct in an array so we need to apply both array flattening and struct flattening
player_details = player_details.select(player_details.matchId, F.explode(player_details.participants))
player_details = player_details.select(col("matchId"), col("col.*"))
#finally we drop the unwanted data
player_details = player_details.drop("challenges", "perks")
#our df is ready to be used in our database
player_details.printSchema()
# Out:
# root
#  |-- matchId: string (nullable = true)
#  |-- assists: long (nullable = true)
#  |-- baronKills: long (nullable = true)
#  |-- bountyLevel: long (nullable = true)
#  |-- champExperience: long (nullable = true)
#  |-- champLevel: long (nullable = true)
#  |-- championId: long (nullable = true)
#  |-- championName: string (nullable = true)
#  |-- championTransform: long (nullable = true)
#  |-- consumablesPurchased: long (nullable = true)
#  |-- damageDealtToBuildings: long (nullable = true)
#  |-- damageDealtToObjectives: long (nullable = true)
#  |-- damageDealtToTurrets: long (nullable = true)
#  |-- damageSelfMitigated: long (nullable = true)
#  |-- deaths: long (nullable = true)
#  |-- detectorWardsPlaced: long (nullable = true)
#  |-- doubleKills: long (nullable = true)
#  |-- dragonKills: long (nullable = true)
#  |-- firstBloodAssist: boolean (nullable = true)
#  |-- firstBloodKill: boolean (nullable = true)
#  |-- firstTowerAssist: boolean (nullable = true)
#  |-- firstTowerKill: boolean (nullable = true)
#  |-- gameEndedInEarlySurrender: boolean (nullable = true)
#  |-- gameEndedInSurrender: boolean (nullable = true)
#  |-- goldEarned: long (nullable = true)
#  |-- goldSpent: long (nullable = true)
#  |-- individualPosition: string (nullable = true)
#  |-- inhibitorKills: long (nullable = true)
#  |-- inhibitorTakedowns: long (nullable = true)
#  |-- inhibitorsLost: long (nullable = true)
#  |-- item0: long (nullable = true)
#  |-- item1: long (nullable = true)
#  |-- item2: long (nullable = true)
#  |-- item3: long (nullable = true)
#  |-- item4: long (nullable = true)
#  |-- item5: long (nullable = true)
#  |-- item6: long (nullable = true)
#  |-- itemsPurchased: long (nullable = true)
#  |-- killingSprees: long (nullable = true)
#  |-- kills: long (nullable = true)
#  |-- lane: string (nullable = true)
#  |-- largestCriticalStrike: long (nullable = true)
#  |-- largestKillingSpree: long (nullable = true)
#  |-- largestMultiKill: long (nullable = true)
#  |-- longestTimeSpentLiving: long (nullable = true)
#  |-- magicDamageDealt: long (nullable = true)
#  |-- magicDamageDealtToChampions: long (nullable = true)
#  |-- magicDamageTaken: long (nullable = true)
#  |-- neutralMinionsKilled: long (nullable = true)
#  |-- nexusKills: long (nullable = true)
#  |-- nexusLost: long (nullable = true)
#  |-- nexusTakedowns: long (nullable = true)
#  |-- objectivesStolen: long (nullable = true)
#  |-- objectivesStolenAssists: long (nullable = true)
#  |-- participantId: long (nullable = true)
#  |-- pentaKills: long (nullable = true)
#  |-- physicalDamageDealt: long (nullable = true)
#  |-- physicalDamageDealtToChampions: long (nullable = true)
#  |-- physicalDamageTaken: long (nullable = true)
#  |-- profileIcon: long (nullable = true)
#  |-- puuid: string (nullable = true)
#  |-- quadraKills: long (nullable = true)
#  |-- riotIdName: string (nullable = true)
#  |-- riotIdTagline: string (nullable = true)
#  |-- role: string (nullable = true)
#  |-- sightWardsBoughtInGame: long (nullable = true)
#  |-- spell1Casts: long (nullable = true)
#  |-- spell2Casts: long (nullable = true)
#  |-- spell3Casts: long (nullable = true)
#  |-- spell4Casts: long (nullable = true)
#  |-- summoner1Casts: long (nullable = true)
#  |-- summoner1Id: long (nullable = true)
#  |-- summoner2Casts: long (nullable = true)
#  |-- summoner2Id: long (nullable = true)
#  |-- summonerId: string (nullable = true)
#  |-- summonerLevel: long (nullable = true)
#  |-- summonerName: string (nullable = true)
#  |-- teamEarlySurrendered: boolean (nullable = true)
#  |-- teamId: long (nullable = true)
#  |-- teamPosition: string (nullable = true)
#  |-- timeCCingOthers: long (nullable = true)
#  |-- timePlayed: long (nullable = true)
#  |-- totalDamageDealt: long (nullable = true)
#  |-- totalDamageDealtToChampions: long (nullable = true)
#  |-- totalDamageShieldedOnTeammates: long (nullable = true)
#  |-- totalDamageTaken: long (nullable = true)
#  |-- totalHeal: long (nullable = true)
#  |-- totalHealsOnTeammates: long (nullable = true)
#  |-- totalMinionsKilled: long (nullable = true)
#  |-- totalTimeCCDealt: long (nullable = true)
#  |-- totalTimeSpentDead: long (nullable = true)
#  |-- totalUnitsHealed: long (nullable = true)
#  |-- tripleKills: long (nullable = true)
#  |-- trueDamageDealt: long (nullable = true)
#  |-- trueDamageDealtToChampions: long (nullable = true)
#  |-- trueDamageTaken: long (nullable = true)
#  |-- turretKills: long (nullable = true)
#  |-- turretTakedowns: long (nullable = true)
#  |-- turretsLost: long (nullable = true)
#  |-- unrealKills: long (nullable = true)
#  |-- visionScore: long (nullable = true)
#  |-- visionWardsBoughtInGame: long (nullable = true)
#  |-- wardsKilled: long (nullable = true)
#  |-- wardsPlaced: long (nullable = true)
#  |-- win: boolean (nullable = true)

# %% [markdown]
# # Load from DB

# %%
#get the matches table
matches = spark.read.format("jdbc").options(
    url='jdbc:postgresql://localhost:5432/RIOT2', # jdbc:postgresql://<host>:<port>/<database>
    dbtable='matches',
    user='postgres',
    password='1234',
    driver='org.postgresql.Driver').load()
matches.printSchema()

# %%
matches.groupBy("gameMode").count().show()
# Out:
# +-----------------+-----+
# |         gameMode|count|
# +-----------------+-----+
# |TUTORIAL_MODULE_3|    7|
# |             ARAM|  122|
# |TUTORIAL_MODULE_2|    3|
# |          CLASSIC|  428|
# |TUTORIAL_MODULE_1|    7|
# +-----------------+-----+

# %%
#filter out tutorial games
matches.createOrReplaceTempView("matches")

matches = spark.sql("SELECT * FROM matches WHERE gamemode == 'ARAM' OR gamemode == 'CLASSIC';")
matches.groupBy("gameMode").count().show()
# Out:
# +--------+-----+
# |gameMode|count|
# +--------+-----+
# |    ARAM|  122|
# | CLASSIC|  428|
# +--------+-----+

# %%
matches.take(1)
# Out:
# [Row(gameCreation=1646439824000, gameDuration=1492, gameEndTimestamp=1646441376127, gameId=5762695498, gameMode='ARAM', gameName='teambuilder-match-5762695498', gameStartTimestamp=1646439884149, gameType='MATCHED_GAME', gameVersion='12.5.425.9171', mapId=12, platformId='EUW1', queueId=450, tournamentCode='', matchId='EUW_5762695498')]

# %%
#Making Timestamps readable. We have to divide by 1000 and round because the server takes millisecond timestamps
matches = matches.withColumn('gameStartTimestamp', col('gameStartTimestamp')/1000)
matches = matches.withColumn('gameStartTimestamp', round('gameStartTimestamp'))
matches = matches.withColumn('gameStartTimestamp', col('gameStartTimestamp').cast("timestamp"))
matches = matches.withColumn('gameCreation', col('gameCreation')/1000)
matches = matches.withColumn('gameCreation', round('gameCreation'))
matches = matches.withColumn('gameCreation', col('gameCreation').cast("timestamp"))
matches = matches.withColumn('gameEndTimestamp', col('gameEndTimestamp')/1000)
matches = matches.withColumn('gameEndTimestamp', round('gameEndTimestamp'))
matches = matches.withColumn('gameEndTimestamp', col('gameEndTimestamp').cast("timestamp"))

# %%
matches.select('gameStartTimestamp', 'gameEndTimestamp').sort('gameStartTimestamp' ,ascending=True).show(600)
# Out:
# +-------------------+-------------------+
# | gameStartTimestamp|   gameEndTimestamp|
# +-------------------+-------------------+
# |2022-03-05 01:14:59|2022-03-05 01:34:31|
# |2022-03-05 01:15:23|2022-03-05 01:38:34|
# |2022-03-05 01:15:26|2022-03-05 01:33:10|
# |2022-03-05 01:15:29|2022-03-05 01:30:26|
# |2022-03-05 01:15:31|2022-03-05 01:38:14|
# |2022-03-05 01:15:35|2022-03-05 01:41:22|
# |2022-03-05 01:15:35|2022-03-05 01:31:27|
# |2022-03-05 01:15:37|2022-03-05 01:38:27|
# |2022-03-05 01:15:39|2022-03-05 01:48:45|
# |2022-03-05 01:15:40|2022-03-05 01:35:30|
# |2022-03-05 01:15:46|2022-03-05 01:40:27|
# |2022-03-05 01:15:51|2022-03-05 01:45:59|
# |2022-03-05 01:15:52|2022-03-05 01:37:34|
# |2022-03-05 01:15:54|2022-03-05 01:39:05|
# |2022-03-05 01:16:03|2022-03-05 01:31:37|
# |2022-03-05 01:16:08|2022-03-05 01:39:51|
# |2022-03-05 01:16:08|2022-03-05 01:31:10|
# |2022-03-05 01:16:09|2022-03-05 01:36:01|
# |2022-03-05 01:16:10|2022-03-05 01:41:17|
# |2022-03-05 01:16:18|2022-03-05 01:47:34|
# |2022-03-05 01:16:28|2022-03-05 01:39:49|
# |2022-03-05 01:16:31|2022-03-05 01:37:41|
# |2022-03-05 01:16:31|2022-03-05 01:36:32|
# |2022-03-05 01:16:34|2022-03-05 01:31:53|
# |2022-03-05 01:16:44|2022-03-05 01:44:06|
# |2022-03-05 01:16:45|2022-03-05 01:47:21|
# |2022-03-05 01:16:45|2022-03-05 01:36:13|
# |2022-03-05 01:16:51|2022-03-05 01:55:59|
# |2022-03-05 01:16:55|2022-03-05 01:43:03|
# |2022-03-05 01:17:06|2022-03-05 01:33:32|
# |2022-03-05 01:17:06|2022-03-05 01:44:16|
# |2022-03-05 01:17:07|2022-03-05 01:47:08|
# |2022-03-05 01:17:07|2022-03-05 01:48:39|
